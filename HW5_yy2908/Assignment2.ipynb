# %% [markdown]
# # Imports (compatible for Python 2 and Python 3)

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
query = '''SELECT * FROM fb55.citibike; '''
table = get_data(query)
table.head(5)
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# 2  2015-02-01 14:11:00+00               317        2759
# 3  2015-02-01 17:32:00+00               483        4893
# 4  2015-02-01 21:40:00+00               477        6090
#
#    start_station_latitude  end_station_id end_station_name  \
# 0               40.738274             229   Great Jones St
# 1               40.760094             490  8 Ave & W 33 St
# 2               40.724537             466  W 25 St & 6 Ave
# 3               40.732233             345  W 13 St & 6 Ave
# 4               40.756405             490  8 Ave & W 33 St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.727434             -73.993790   19718  Subscriber
# 1             40.751551             -73.993934   21501  Subscriber
# 2             40.743954             -73.991449   14788  Subscriber
# 3             40.736494             -73.997044   16219  Subscriber
# 4             40.751551             -73.993934   18266    Customer
#
#    birth_year  gender
# 0      1961.0       1
# 1      1981.0       1
# 2      1990.0       1
# 3      1961.0       1
# 4         NaN       0

# %%
#Task1
#sort by start_station_id
query = '''
SELECT * FROM fb55.citibike
where tripduration <= 10800
order by start_station_id desc
limit 10
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom          start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  South End Ave & Liberty St                   NaN     1932
# 1       NaN  South End Ave & Liberty St                   NaN     2094
# 2       NaN  South End Ave & Liberty St                   NaN     1698
# 3       NaN  South End Ave & Liberty St                   NaN     1657
# 4       NaN  South End Ave & Liberty St                   NaN     1402
# 5       NaN  South End Ave & Liberty St                   NaN     1542
# 6       NaN  South End Ave & Liberty St                   NaN      361
# 7       NaN  South End Ave & Liberty St                   NaN     1297
# 8       NaN  South End Ave & Liberty St                   NaN     1576
# 9       NaN  South End Ave & Liberty St                   NaN     2271
#
#    start_station_longitude  tripduration               starttime  \
# 0               -74.015756           689  2015-02-01 12:25:00+00
# 1               -74.015756           307  2015-02-01 12:42:00+00
# 2               -74.015756           745  2015-02-01 11:57:00+00
# 3               -74.015756           858  2015-02-01 11:53:00+00
# 4               -74.015756          1243  2015-02-01 11:27:00+00
# 5               -74.015756           683  2015-02-01 11:43:00+00
# 6               -74.015756           301  2015-02-01 07:49:00+00
# 7               -74.015756          1900  2015-02-01 11:14:00+00
# 8               -74.015756          7225  2015-02-01 11:46:00+00
# 9               -74.015756           790  2015-02-01 13:01:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 12:36:00+00              3002        1863
# 1  2015-02-01 12:47:00+00              3002        2026
# 2  2015-02-01 12:09:00+00              3002        1628
# 3  2015-02-01 12:07:00+00              3002        1587
# 4  2015-02-01 11:48:00+00              3002        1333
# 5  2015-02-01 11:55:00+00              3002        1472
# 6  2015-02-01 07:54:00+00              3002         293
# 7  2015-02-01 11:45:00+00              3002        1228
# 8  2015-02-01 13:47:00+00              3002        1506
# 9  2015-02-01 13:14:00+00              3002        2205
#
#    start_station_latitude  end_station_id               end_station_name  \
# 0               40.711512             358  Christopher St & Greenwich St
# 1               40.711512             147       Greenwich St & Warren St
# 2               40.711512             369          Washington Pl & 6 Ave
# 3               40.711512             355          Bayard St & Baxter St
# 4               40.711512             360           William St & Pine St
# 5               40.711512             308        St James Pl & Oliver St
# 6               40.711512             417         Barclay St & Church St
# 7               40.711512             525               W 34 St & 11 Ave
# 8               40.711512             499             Broadway & W 60 St
# 9               40.711512             368             Carmine St & 6 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.732916             -74.007114   19309  Subscriber
# 1             40.715422             -74.011220   18386  Subscriber
# 2             40.732241             -74.000264   20901  Subscriber
# 3             40.716021             -73.999744   15748  Subscriber
# 4             40.707179             -74.008873   18288    Customer
# 5             40.713079             -73.998512   16987  Subscriber
# 6             40.712912             -74.010202   19484  Subscriber
# 7             40.755942             -74.002116   17849    Customer
# 8             40.769155             -73.981918   21202    Customer
# 9             40.730386             -74.002150   17004  Subscriber
#
#    birth_year  gender
# 0      1996.0       1
# 1      1984.0       2
# 2      1980.0       1
# 3      1959.0       1
# 4         NaN       0
# 5      1980.0       2
# 6      1980.0       2
# 7         NaN       0
# 8         NaN       0
# 9      1979.0       1

# %%
#sort by tripduration
query = '''
SELECT * FROM fb55.citibike
where tripduration <= 10800
order by tripduration desc
LIMIT 10;
'''
table = get_data(query)
table.tail(5)
# Out:
#    the_geom       start_station_name  the_geom_webmercator  field_1  \
# 5       NaN          W 21 St & 6 Ave                   NaN    15380
# 6       NaN       Broadway & W 58 St                   NaN    25241
# 7       NaN       Broadway & E 22 St                   NaN    19952
# 8       NaN       Broadway & W 60 St                   NaN     7139
# 9       NaN  DeKalb Ave & Hudson Ave                   NaN    11871
#
#    start_station_longitude  tripduration               starttime  \
# 5               -73.994156          9807  2015-02-04 10:53:00+00
# 6               -73.981693          9711  2015-02-05 11:12:00+00
# 7               -73.989551          9572  2015-02-04 19:09:00+00
# 8               -73.981918          9556  2015-02-02 13:25:00+00
# 9               -73.981013          9373  2015-02-03 19:25:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 5  2015-02-04 13:36:00+00               435       15336
# 6  2015-02-05 13:54:00+00               457       25203
# 7  2015-02-04 21:48:00+00               402       19897
# 8  2015-02-02 16:05:00+00               499        7073
# 9  2015-02-03 22:01:00+00               324       11810
#
#    start_station_latitude  end_station_id         end_station_name  \
# 5               40.741740             435          W 21 St & 6 Ave
# 6               40.766953            2021          W 45 St & 8 Ave
# 7               40.740343             517    Pershing Square South
# 8               40.769155             499       Broadway & W 60 St
# 9               40.689888             324  DeKalb Ave & Hudson Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 5             40.741740             -73.994156   18088  Subscriber
# 6             40.759291             -73.988597   14726  Subscriber
# 7             40.751581             -73.977910   14691  Subscriber
# 8             40.769155             -73.981918   14802  Subscriber
# 9             40.689888             -73.981013   15018  Subscriber
#
#    birth_year  gender
# 5        1985       1
# 6        1962       1
# 7        1966       2
# 8        1940       1
# 9        1968       1

# %%
#sort by both
query = '''
SELECT * FROM fb55.citibike
ORDER BY start_station_id ASC,tripduration DESC
LIMIT 10;
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9115
# 1       NaN   W 52 St & 11 Ave                   NaN     2051
# 2       NaN   W 52 St & 11 Ave                   NaN    40355
# 3       NaN   W 52 St & 11 Ave                   NaN    12996
# 4       NaN   W 52 St & 11 Ave                   NaN    11359
# 5       NaN   W 52 St & 11 Ave                   NaN    13695
# 6       NaN   W 52 St & 11 Ave                   NaN     9802
# 7       NaN   W 52 St & 11 Ave                   NaN    11301
# 8       NaN   W 52 St & 11 Ave                   NaN    20364
# 9       NaN   W 52 St & 11 Ave                   NaN    24990
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929          2099  2015-02-03 10:28:00+00
# 1               -73.993929          1944  2015-02-01 12:39:00+00
# 2               -73.993929          1914  2015-02-07 09:49:00+00
# 3               -73.993929          1801  2015-02-04 06:32:00+00
# 4               -73.993929          1678  2015-02-03 18:21:00+00
# 5               -73.993929          1537  2015-02-04 08:07:00+00
# 6               -73.993929          1535  2015-02-03 14:23:00+00
# 7               -73.993929          1518  2015-02-03 18:16:00+00
# 8               -73.993929          1493  2015-02-04 19:47:00+00
# 9               -73.993929          1388  2015-02-05 10:34:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-03 11:02:00+00                72        9054
# 1  2015-02-01 13:12:00+00                72        1983
# 2  2015-02-07 10:21:00+00                72       40341
# 3  2015-02-04 07:02:00+00                72       12938
# 4  2015-02-03 18:49:00+00                72       11298
# 5  2015-02-04 08:33:00+00                72       13647
# 6  2015-02-03 14:48:00+00                72        9742
# 7  2015-02-03 18:42:00+00                72       11240
# 8  2015-02-04 20:12:00+00                72       20309
# 9  2015-02-05 10:58:00+00                72       24953
#
#    start_station_latitude  end_station_id          end_station_name  \
# 0               40.767272             328   Watts St & Greenwich St
# 1               40.767272             328   Watts St & Greenwich St
# 2               40.767272             328   Watts St & Greenwich St
# 3               40.767272             328   Watts St & Greenwich St
# 4               40.767272              79  Franklin St & W Broadway
# 5               40.767272             487       E 20 St & FDR Drive
# 6               40.767272             334           W 20 St & 7 Ave
# 7               40.767272             476           E 31 St & 3 Ave
# 8               40.767272              79  Franklin St & W Broadway
# 9               40.767272             127     Barrow St & Hudson St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.724055             -74.009660   18653  Subscriber
# 1             40.724055             -74.009660   17849    Customer
# 2             40.724055             -74.009660   21520  Subscriber
# 3             40.724055             -74.009660   15161  Subscriber
# 4             40.719116             -74.006667   21500  Subscriber
# 5             40.733143             -73.975739   18900  Subscriber
# 6             40.742388             -73.997262   15117  Subscriber
# 7             40.743943             -73.979661   19039  Subscriber
# 8             40.719116             -74.006667   21080  Subscriber
# 9             40.731724             -74.006744   19672  Subscriber
#
#    birth_year  gender
# 0      1966.0       2
# 1         NaN       0
# 2      1966.0       2
# 3      1959.0       2
# 4      1964.0       1
# 5      1977.0       2
# 6      1956.0       2
# 7      1971.0       1
# 8      1964.0       1
# 9      1974.0       1

# %%
#List all unique start_station_id values 
query = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
order by start_station_id
'''
table = get_data(query)
table.head(5)
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                79         NaN
# 2                82         NaN
# 3                83         NaN
# 4               116         NaN

# %%
#Aggregation functions:Count the number of trips (aka wc -l in SQL),Find the average/min/max trip duration
query = '''
SELECT count(start_station_id) as number_trip,
avg(tripduration) as avg_duration,
min(tripduration) as min_duration,
max(tripduration) as max_duration
FROM fb55.citibike
'''
table = get_data(query)
table.head()
# Out:
#    number_trip  avg_duration  min_duration  max_duration
# 0        46200    675.865823            60         43016

# %%
#Task2
#Selecting trips started on Feb-02-2015 only 
query = '''
SELECT * FROM fb55.citibike
where starttime >= '2015-02-02 00:00' and 
starttime < '2015-02-03 00:00'

'''
table = get_data(query)
table.head(5)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.979955          1312  2015-02-02 11:07:00+00
# 3               -74.004432           444  2015-02-02 00:40:00+00
# 4               -74.004432           438  2015-02-02 00:40:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# 2  2015-02-02 11:29:00+00               393        6920
# 3  2015-02-02 00:48:00+00               463        6477
# 4  2015-02-02 00:47:00+00               463        6478
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.745168             537  Lexington Ave & E 24 St
# 1               40.716059             461          E 20 St & 2 Ave
# 2               40.722992             476          E 31 St & 3 Ave
# 3               40.742065             489         10 Ave & W 28 St
# 4               40.742065             489         10 Ave & W 28 St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.740259             -73.984092   18048  Subscriber
# 1             40.735877             -73.982050   19732    Customer
# 2             40.743943             -73.979661   17720  Subscriber
# 3             40.750664             -74.001768   20233  Subscriber
# 4             40.750664             -74.001768   20264  Subscriber
#
#    birth_year  gender
# 0      1977.0       1
# 1         NaN       0
# 2      1955.0       1
# 3      1971.0       1
# 4      1981.0       2

# %%
#Selecting trips started on the weekends 
#What are average trip duration during weekends?
query = '''
SELECT * FROM fb55.citibike
where extract(dow from starttime) in (0,6)
'''
table = get_data(query)
table.head()
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# 2  2015-02-01 14:11:00+00               317        2759
# 3  2015-02-01 17:32:00+00               483        4893
# 4  2015-02-01 21:40:00+00               477        6090
#
#    start_station_latitude  end_station_id end_station_name  \
# 0               40.738274             229   Great Jones St
# 1               40.760094             490  8 Ave & W 33 St
# 2               40.724537             466  W 25 St & 6 Ave
# 3               40.732233             345  W 13 St & 6 Ave
# 4               40.756405             490  8 Ave & W 33 St
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.727434             -73.993790   19718  Subscriber
# 1             40.751551             -73.993934   21501  Subscriber
# 2             40.743954             -73.991449   14788  Subscriber
# 3             40.736494             -73.997044   16219  Subscriber
# 4             40.751551             -73.993934   18266    Customer
#
#    birth_year  gender
# 0      1961.0       1
# 1      1981.0       1
# 2      1990.0       1
# 3      1961.0       1
# 4         NaN       0

# %%
query = '''
SELECT avg(tripduration) as avg_duartion FROM fb55.citibike
where extract(dow from starttime) in (0,6)
'''
table = get_data(query)
table.head()
# Out:
#    avg_duartion  Unnamed: 1
# 0    662.942181         NaN

# %%
#Can we do the same for weekday?
query = '''
SELECT * FROM fb55.citibike
where extract(dow from starttime) in (1,2,3,4,5)
'''
table = get_data(query)
table.head()
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN       E 39 St & 3 Ave                   NaN     8327
# 3       NaN      10 Ave & W 28 St                   NaN     9435
# 4       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.976049           441  2015-02-03 08:02:00+00
# 3               -74.001768          1475  2015-02-03 12:31:00+00
# 4               -73.990697           420  2015-02-03 16:45:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# 2  2015-02-03 08:10:00+00               167        8263
# 3  2015-02-03 12:56:00+00               489        9375
# 4  2015-02-03 16:52:00+00               403       10411
#
#    start_station_latitude  end_station_id         end_station_name  \
# 0               40.745168             537  Lexington Ave & E 24 St
# 1               40.716059             461          E 20 St & 2 Ave
# 2               40.748901             526          E 33 St & 5 Ave
# 3               40.750664             455          1 Ave & E 44 St
# 4               40.725029             297          E 15 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  bikeid    usertype  \
# 0             40.740259             -73.984092   18048  Subscriber
# 1             40.735877             -73.982050   19732    Customer
# 2             40.747659             -73.984907   21518  Subscriber
# 3             40.750020             -73.969053   19863  Subscriber
# 4             40.734232             -73.986923   19257  Subscriber
#
#    birth_year  gender
# 0      1977.0       1
# 1         NaN       0
# 2      1975.0       1
# 3      1984.0       2
# 4      1984.0       1

# %%
query = '''
SELECT avg(tripduration) as avg_duartion FROM fb55.citibike
where extract(dow from starttime) in (1,2,3,4,5)
'''
table = get_data(query)
table.head()
# Out:
#    avg_duartion  Unnamed: 1
# 0    681.052292         NaN

# %%
#Task3
#Showing the list of start station locations using groupby
query = '''
SELECT distinct on (start_station_id)
start_station_id, start_station_latitude, start_station_longitude
FROM fb55.citibike
GROUP BY start_station_id, start_station_latitude, start_station_longitude

'''
table = get_data(query)
table.head()
# Out:
#    start_station_id  start_station_latitude  start_station_longitude
# 0                72               40.767272               -73.993929
# 1                79               40.719116               -74.006667
# 2                82               40.711174               -74.000165
# 3                83               40.683826               -73.976323
# 4               116               40.741776               -74.001497

# %%
#Showing the number of trips started per station
#but only for stations within 500m of Time Square!The coordinates of Time Square is (40.7577,-73.9857
query = '''
select count(start_station_id),
start_station_name as start_station_name
from fb55.citibike
where st_dwithin(
CDB_LatLng(start_station_latitude, start_station_longitude)::geography, CDB_LatLng(40.7577, -73.9857)::geography, 500)
GROUP BY start_station_id, start_station_name
'''
table = get_data(query)
table.head()
# Out:
#    count  start_station_name
# 0    213  Broadway & W 49 St
# 1    251  Broadway & W 41 St
# 2    507     W 41 St & 8 Ave
# 3    141     W 45 St & 6 Ave
# 4    112     W 43 St & 6 Ave

# %%
#Task4
#Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare! 
query = '''
select avg(tripduration) as avg_durations, start_station_name
from fb55.citibike
where st_dwithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, CDB_LatLng(40.7577, -73.9857)::geography, 500) 
and extract(DOW FROM starttime) in (0,6)
group by start_station_latitude, start_station_longitude, start_station_name
order by avg_durations DESC
'''
table = get_data(query)
table.head()
# Out:
#    avg_durations  start_station_name
# 0    1010.104167  Broadway & W 49 St
# 1     762.931818     W 45 St & 8 Ave
# 2     683.121212  Broadway & W 41 St
# 3     675.400000     W 45 St & 6 Ave
# 4     643.260274     W 41 St & 8 Ave

# %%
#Extra: create lines for trips started from stations within 500m of Times Squares and lasted less than 2 hours. The number of trips per each pair of stations are output as attributes of these lines. 
query = '''

select st_makeline(CDB_LatLng(start_station_latitude,start_station_longitude), CDB_LatLng(end_station_latitude,end_station_longitude)) as the_geom_webmercator,
count(start_station_id) as num_trips, start_station_name, end_station_name
from citibike
where st_dwithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, CDB_LatLng(40.7577,-73.9857)::geography, 500) and tripduration < 60 * 60 * 2
group by start_station_latitude, start_station_longitude, end_station_latitude, end_station_longitude, start_station_name, end_station_name
'''
table = get_data(query)
table.head()
# Out:
#                                 the_geom_webmercator  num_trips  \
# 0  0102000020E610000002000000BE51C821247F52C02199...          1
# 1  0102000020E610000002000000BE51C821247F52C02199...          1
# 2  0102000020E610000002000000BE51C821247F52C02199...          1
# 3  0102000020E610000002000000BE51C821247F52C02199...          1
# 4  0102000020E610000002000000BE51C821247F52C02199...          1
#
#    start_station_name          end_station_name
# 0  Broadway & W 41 St   Pearl St & Anchorage Pl
# 1  Broadway & W 41 St                 Cherry St
# 2  Broadway & W 41 St     Forsyth St & Canal St
# 3  Broadway & W 41 St      Allen St & Hester St
# 4  Broadway & W 41 St  Elizabeth St & Hester St
