# %%
from __future__ import print_function
__author__ = "Yaxuan Yin, CUSP NYU 2018"

# %%
import os
import sys
# you can use the numpy library for random nu
# mber generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html
import numpy as np

# %%
np.random.seed()

# %%
ReprRand = np.random.randn(2,100)

# %%
# run this cell
ReprRand.shape
# Out:
# (2, 100)

# %%
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    np.random.seed()
    ReprRandAll[i]= i * SIGMA * ReprRand

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
import pylab as pl
import matplotlib.cm as cm
import matplotlib.pyplot as plt 
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here
# initialize a plot with size of (8,5)
plot = plt.figure(figsize=(8,5))
# using ocean spectrum them and linspace to create 50 different color gradient between 0 and 1
col = cm.ocean(np.linspace(0, 1, 50))
# plot those numbers
for i in range(50):
    plt.scatter(ReprRandAll[i][0], ReprRandAll[i][1], marker = '*')

# set up label names 
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.title('Figure 1: Distribution Graph', fontsize=20)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
SIGMA_1 = 3
SIGMA_2 = 5
RANDOM = 2
array = np.zeros((50, 2, 100))
# Fill in the numbers
for i in np.arange(0, 50):
    np.random.seed(SEED)
    array[i][0] = i * SIGMA_1 * np.random.randn(100) 
    array[i][1] = (i + RANDOM) * SIGMA_2 * np.random.randn(100)

# %%
plot = plt.figure(figsize=(8,5))
# using magma spectrum them and linspace to create 50 different color gradient between 0 and 1
col = cm.magma(np.linspace(0, 1, 50))
# plot those numbers
for i in range(50):
    plt.scatter(array[i][0], array[i][1], marker = '*')

# set up label names 
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.title('Figure 2: Distribution Graph for Challenge', fontsize=20)
plt.show()
