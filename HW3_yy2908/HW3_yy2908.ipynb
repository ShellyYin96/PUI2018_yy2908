# %%
from __future__ import print_function

# %%
import os

# %%
print("PUIdata", os.getenv("PUIDATA"))
# Out:
# PUIdata None

# %%
os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")

# %%
print("PUIdata", os.getenv("PUIDATA"))
# Out:
# PUIdata /nfshome/yy2908/PUIdata

# %%
import pandas as pd
dhs = pd.read_csv("{}/Popular_Baby_Names.csv".format(os.getenv("PUIDATA")))

# %%
dhs.head(7)
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             SOPHIA
# 1           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              CHLOE
# 2           2011  FEMALE  ASIAN AND PACIFIC ISLANDER              EMILY
# 3           2011  FEMALE  ASIAN AND PACIFIC ISLANDER             OLIVIA
# 4           2011  FEMALE  ASIAN AND PACIFIC ISLANDER               EMMA
# 5           2011  FEMALE  ASIAN AND PACIFIC ISLANDER           ISABELLA
# 6           2011  FEMALE  ASIAN AND PACIFIC ISLANDER            TIFFANY
#
#    Count  Rank
# 0    119     1
# 1    106     2
# 2     93     3
# 3     89     4
# 4     75     5
# 5     67     6
# 6     54     7

# %%
dhs.tail(3)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 11342           2016  FEMALE  BLACK NON HISPANIC              Tiana     10
# 11343           2016  FEMALE  BLACK NON HISPANIC             Violet     10
# 11344           2016  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 11342    43
# 11343    43
# 11344    43

# %%
dhs.columns
# Out:
# Index(['Year of Birth', 'Gender', 'Ethnicity', 'Child's First Name', 'Count',
#        'Rank'],
#       dtype='object')

# %%
dhs.size
# Out:
# 68070

# %%
dhs_2c = dhs[['Rank', 'Count']]

# %%
dhs_2c.head()
# Out:
#    Rank  Count
# 0     1    119
# 1     2    106
# 2     3     93
# 3     4     89
# 4     5     75

# %%
dhs_2c.plot(x='Rank', y='Count')
plt.title("Rank vs. Count", fontsize=16)
# Out:
# Text(0.5,1,'Rank vs. Count')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url="https://data.cityofnewyork.us/resource/g374-eanh.json"

# %%
df = pd.read_json(url)

# %%
df.head(300)
# Out:
#      brth_yr  cnt                      ethcty    gndr         nm  rnk
# 0       2011   24  ASIAN AND PACIFIC ISLANDER  FEMALE    ABIGAIL   24
# 1       2011   13  ASIAN AND PACIFIC ISLANDER  FEMALE        ADA   35
# 2       2011   13  ASIAN AND PACIFIC ISLANDER  FEMALE      AISHA   35
# 3       2011   10  ASIAN AND PACIFIC ISLANDER  FEMALE       AIZA   38
# 4       2011   12  ASIAN AND PACIFIC ISLANDER  FEMALE     ALEENA   36
# 5       2011   10  ASIAN AND PACIFIC ISLANDER  FEMALE      ALEXA   38
# 6       2011   13  ASIAN AND PACIFIC ISLANDER  FEMALE  ALEXANDRA   35
# 7       2011   27  ASIAN AND PACIFIC ISLANDER  FEMALE      ALICE   21
# 8       2011   25  ASIAN AND PACIFIC ISLANDER  FEMALE      ALINA   23
# 9       2011   10  ASIAN AND PACIFIC ISLANDER  FEMALE     ALISHA   38
# 10      2011   12  ASIAN AND PACIFIC ISLANDER  FEMALE     ALIYAH   36
# 11      2011   17  ASIAN AND PACIFIC ISLANDER  FEMALE    ALLISON   31
# ...

# %%
dhs_3c = df[['cnt', 'gndr', 'rnk']]

# %%
dhs_3c.rename(columns = {'cnt':'Count', 
               'gndr':'Gender', 
               'rnk': 'Rank'}, inplace=True)
# Out:
# /nfshome/yy2908/.conda/envs/Shelly/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
ax = dhs_3c.plot(x='Count', y='Rank');
ax.set_ylabel("Count vs. Rank");
